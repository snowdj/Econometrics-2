# %%
using DataFrames, DataFramesMeta
card = readtable("../Data/card.csv") # how to read CSV data into DataFrame
size(card)
names(card)
head(card)
describe(card)
# Out:
# INFO: Recompiling stale cache file /home/michael/.julia/lib/v0.6/DataFrames.ji for module DataFrames.
# wage
# Summary Stats:
# Mean:           577.282392
# Minimum:        100.000000
# 1st Quartile:   394.250000
# Median:         537.500000
# 3rd Quartile:   708.750000
# Maximum:        2404.000000
# Length:         3010
# Type:           Int64
# Number Missing: 0
# % Missing:      0.000000
#
# nearc4
# Summary Stats:
# Mean:           0.682060
# Minimum:        0.000000
# 1st Quartile:   0.000000
# Median:         1.000000
# 3rd Quartile:   1.000000
# Maximum:        1.000000
# Length:         3010
# Type:           Int64
# Number Missing: 0
# % Missing:      0.000000
#
# educ
# Summary Stats:
# Mean:           13.263455
# Minimum:        1.000000
# 1st Quartile:   12.000000
# Median:         13.000000
# 3rd Quartile:   16.000000
# Maximum:        18.000000
# Length:         3010
# Type:           Int64
# Number Missing: 0
# % Missing:      0.000000
#
# age
# Summary Stats:
# ...

# %%
using StatPlots
@df card density(:exper)
# Out:
# WARNING: _show is not defined for this backend. m=text/plain
